# %%
from transformers import pipeline

# %%
import transformers

# %%
transformers.__version__
# Out:
# '5.16.1'

# %%
# !pip uninstall transformers
# !pip install transformers==4.5
# Out:
# Found existing installation: transformers 5.16.1
# Uninstalling transformers-5.16.1:
#   Would remove:
#     /usr/local/bin/transformers
#     /usr/local/lib/python3.13/dist-packages/transformers-5.16.1.dist-info/*
#     /usr/local/lib/python3.13/dist-packages/transformers/*
# Proceed (Y/n)? y
#   Successfully uninstalled transformers-5.16.1
# ...
#   Using cached transformers-4.5.0-py3-none-any.whl.metadata (41 kB)
# ...
#   Using cached sacremoses-0.2.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached tokenizers-0.10.3.tar.gz (212 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Using cached transformers-4.5.0-py3-none-any.whl (2.1 MB)
# Using cached sacremoses-0.2.0-py3-none-any.whl (867 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
# ...

# %%
c = pipeline('question-answering')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2435/4033787829.py in <cell line: 0>()
# ----> 1 c = pipeline('question-answering')
#
# /usr/local/lib/python3.13/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     972             )
#     973     else:
# --> 974         normalized_task, targeted_task, task_options = check_task(task)
#     975         if pipeline_class is None:
#     976             pipeline_class = targeted_task["impl"]
#
# /usr/local/lib/python3.13/dist-packages/transformers/pipelines/__init__.py in check_task(task)
#     357
#     358     """
# --> 359     return PIPELINE_REGISTRY.check_task(task)
#     360
#     361
#
# ...

# %%
import pandas as pd

# %%
t = pd.DataFrame({
    "Name":['Ahmed','Mohamed',"Heba"],
    "Salary":["1000",'5000','2000']
})

# %%
c(table=t,query='Who has the high salary?')
# Out:
# {'answer': 'Mohamed',
#  'coordinates': [(1, 0)],
#  'cells': ['Mohamed'],
#  'aggregator': 'NONE'}

# %%
get_supported_tasks()
# Out:
# ['any-to-any',
#  'audio-classification',
#  'automatic-speech-recognition',
#  'depth-estimation',
#  'document-question-answering',
#  'feature-extraction',
#  'fill-mask',
#  'image-classification',
#  'image-feature-extraction',
#  'image-segmentation',
#  'image-text-to-text',
#  'keypoint-matching',
#  'mask-generation',
#  'ner',
#  'object-detection',
#  'sentiment-analysis',
#  'table-question-answering',
#  'text-classification',
#  'text-generation',
#  'text-to-audio',
#  'text-to-speech',
#  'token-classification',
#  'video-classification',
#  'zero-shot-audio-classification',
#  'zero-shot-classification',
#  'zero-shot-image-classification',
#  'zero-shot-object-detection']
